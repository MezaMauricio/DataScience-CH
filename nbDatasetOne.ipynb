# %%
import pandas

dataset1 = 'datasetOne.csv'


set1 = pandas.read_csv(dataset1, header=0)


print(set1.shape)
print (set1.head(10))
# Out:
# C:\Users\Usuario-pc\AppData\Local\Temp\ipykernel_17928\3175337541.py:7: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   set1 = pandas.read_csv(dataset1, header=0)
# (570011, 35)
#    Unnamed: 0.1  Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 0             0           0  200501BS00001               525680.0
# 1             1           1  200501BS00002               524170.0
# 2             2           2  200501BS00003               524520.0
# 3             3           3  200501BS00004               526900.0
# 4             4           4  200501BS00005               528060.0
# 5             5           5  200501BS00006               524770.0
# 6             6           6  200501BS00007               524220.0
# 7             7           7  200501BS00009               525890.0
# 8             8           8  200501BS00010               527350.0
# 9             9           9  200501BS00011               524550.0
#
# ...
